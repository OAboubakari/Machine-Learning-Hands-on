# %%
import pandas as pd
import numpy as np

# %%
# Reading the dataset
data = pd.read_csv('https://gitlab.com/AnalyticsIndiaMagazine/practicedatasets/-/raw/main/bootcamp/logistic_regression/diabetes.csv')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Defining input and output faetures
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
print(X.shape, y.shape)
# Out:
# (768, 8) (768,)

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train ,y_test = train_test_split(X,y,test_size = 0.1302, shuffle=True, random_state = 0)

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 162            0      114             80             34      285  44.2
# 156            2       99             52             15       94  24.6
# 10             4      110             92              0        0  37.6
# 68             1       95             66             13       38  19.6
# 267            2      128             64             42        0  40.0
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 192            7      159             66              0        0  30.4
# 629            4       94             65             22        0  24.7
# 559           11       85             74              0        0  30.1
# 684            5      136             82              0        0   0.0
#
#      DiabetesPedigreeFunction  Age
# 162                     0.167   27
# 156                     0.637   21
# ...

# %%
X_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661            1      199             76             43        0  42.9
# 122            2      107             74             30      100  33.6
# 113            4       76             62              0        0  34.0
# 14             5      166             72             19      175  25.8
# 529            0      111             65              0        0  24.6
# ..           ...      ...            ...            ...      ...   ...
# 572            3      111             58             31       44  29.5
# 638            7       97             76             32       91  40.9
# 608            0      152             82             39      272  41.5
# 39             4      111             72             47      207  37.1
# 406            4      115             72              0        0  28.9
#
#      DiabetesPedigreeFunction  Age
# 661                     1.394   22
# 122                     0.404   23
# ...

# %%
#feature Scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train) # fit for training set
X_test = scaler.transform(X_test) # transform for test set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-34f300d2b0e9> in <module>
# ----> 1 X_train = scaler.fit_transform(X_train) # fit for training set
#       2 X_test = scaler.transform(X_test) # transform for test set
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
# ...

# %%
#Training the model
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-5bf6a8530af9> in <module>
#       2 from sklearn.linear_model import LogisticRegression
#       3 log_reg = LogisticRegression()
# ----> 4 log_reg.fit(X_train,y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# ...
